# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
import sys
import pandas as pd

# %%
#importiere Werte von Auswertung_Berufe.ipynb
#Bing
# %store -r under_50_m_bing
# %store -r over_50_m_bing
# %store -r under_50_f_bing 
# %store -r over_50_f_bing
#Bing einzeln
# %store -r under_50_m_bing_e 
# %store -r over_50_m_bing_e 
# %store -r under_50_f_bing_e 
# %store -r over_50_f_bing_e
#Google
# %store -r under_50_m_google 
# %store -r over_50_m_google
# %store -r under_50_f_google 
# %store -r over_50_f_google
#Google einzeln
# %store -r under_50_m_google_e 
# %store -r over_50_m_google_e 
# %store -r under_50_f_google_e 
# %store -r over_50_f_google_e
#Deepl
# %store -r under_50_m_deepl
# %store -r over_50_m_deepl
# %store -r under_50_f_deepl 
# %store -r over_50_f_deepl
#Deepl
# %store -r under_50_m_deepl 
# %store -r over_50_m_deepl
# %store -r under_50_f_deepl 
# %store -r over_50_f_deepl
#Deepl einzeln
# %store -r under_50_m_deepl_e 
# %store -r over_50_m_deepl_e 
# %store -r under_50_f_deepl_e 
# %store -r over_50_f_deepl_e
#GPT
# %store -r under_50_m_gpt
# %store -r over_50_m_gpt 
# %store -r under_50_f_gpt 
# %store -r over_50_f_gpt
#GPT einzeln
# %store -r under_50_m_gpt_e 
# %store -r over_50_m_gpt_e 
# %store -r under_50_f_gpt_e 
# %store -r over_50_f_gpt_e

# %%
#Bing
# %store -r percent_masc_bing
# %store -r percent_fem_bing
# %store -r percent_gendern_bing
#Bing einzeln
# %store -r percent_masc_bing_e
# %store -r percent_fem_bing_e
# %store -r percent_gendern_bing_e
#Google
# %store -r percent_masc_google
# %store -r percent_fem_google
# %store -r percent_gendern_google
#Google einzeln
# %store -r percent_masc_google_e
# %store -r percent_fem_google_e
# %store -r percent_gendern_google_e
#Deepl
# %store -r percent_masc_deepl
# %store -r percent_fem_deepl
# %store -r percent_gendern_deepl
#Deepl einzeln
# %store -r percent_masc_deepl_e
# %store -r percent_fem_deepl_e
# %store -r percent_gendern_deepl_e
#GPT
# %store -r percent_masc_gpt
# %store -r percent_fem_gpt
# %store -r percent_gendern_gpt
#GPT einzeln
# %store -r percent_masc_gpt_e
# %store -r percent_fem_gpt_e
# %store -r percent_gendern_gpt_e

# %%
#------------------------- Bing -------------------------------
barWidth = 0.1
fig,ax = plt.subplots(figsize =(6, 4)) 
liste_bing = [percent_masc_bing, percent_fem_bing, percent_gendern_bing] 
einzeln_bing = [percent_masc_bing_e, percent_fem_bing_e, percent_gendern_bing_e]

br1_bing = np.arange(len(liste_bing)) 
br2_bing = [x + barWidth for x in br1_bing] 
br3_bing = [x + barWidth for x in br2_bing] 

plt.bar(br1_bing, liste_bing, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='Bing (Liste)') 
plt.bar(br2_bing, einzeln_bing, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='Bing einzeln') 


plt.xlabel('Bing M:F') 
plt.ylabel('Prozent') 
plt.xticks([r + barWidth for r in range(len(liste_bing))], ['männlich', 'weiblich', 'gendern'])  

plt.legend()
plt.show() 

#------------------------- Deepl -------------------------------
fig,ax = plt.subplots(figsize =(6, 4)) 
liste_deepl = [percent_masc_deepl,percent_fem_deepl, percent_gendern_deepl] 
einzeln_deepl = [percent_masc_deepl_e, percent_fem_deepl_e, percent_gendern_deepl_e] 

br1_deepl = np.arange(len(liste_deepl)) 
br2_deepl = [x + barWidth for x in br1_deepl] 
br3_deepl = [x + barWidth for x in br2_deepl]


plt.bar(br1_deepl, liste_deepl, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='Deepl (Liste)') 
plt.bar(br2_deepl, einzeln_deepl, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='Deepl einzeln') 



plt.xlabel('Deepl M:F') 
plt.ylabel('Prozent') 
plt.xticks([r + barWidth for r in range(len(liste_deepl))], ['männlich', 'weiblich', 'gendern'])  


plt.legend()
plt.show() 

#------------------------- Google -------------------------------
fig,ax = plt.subplots(figsize =(6, 4)) 
liste_google = [percent_masc_google,percent_fem_google, percent_gendern_google] 
einzeln_google = [percent_masc_google_e, percent_fem_google_e, percent_gendern_google_e] 

br1_google = np.arange(len(liste_google)) 
br2_google = [x + barWidth for x in br1_google] 
br3_google = [x + barWidth for x in br2_google]

plt.bar(br1_google, liste_google, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='Google (Liste)') 
plt.bar(br2_google, einzeln_google, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='Google einzeln') 


plt.xlabel('Google M:F') 
plt.ylabel('Prozent') 
plt.xticks([r + barWidth for r in range(len(liste_google))], ['männlich', 'weiblich', 'gendern'])  


plt.legend()
plt.show() 

#------------------------- GPT -------------------------------
fig,ax = plt.subplots(figsize =(6, 4)) 
liste_gpt = [percent_masc_gpt,percent_fem_gpt, percent_gendern_gpt] 
einzeln_gpt = [percent_masc_gpt_e, percent_fem_gpt_e, percent_gendern_gpt_e] 

br1_gpt = np.arange(len(liste_gpt)) 
br2_gpt = [x + barWidth for x in br1_gpt] 
br3_gpt = [x + barWidth for x in br2_gpt]


plt.bar(br1_gpt, liste_gpt, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='GPT (Liste)') 
plt.bar(br2_gpt, einzeln_gpt, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='GPT einzeln') 


plt.xlabel('GPT M:F') 
plt.ylabel('Prozent') 
plt.xticks([r + barWidth for r in range(len(liste_gpt))], ['männlich', 'weiblich', 'gendern'])  

plt.legend()
plt.show()

# %%
#------------------------- Bing -------------------------------
barWidth = 0.1
fig = plt.subplots(figsize =(6, 4)) 

liste_m_bing = [under_50_m_bing,  over_50_m_bing] #st nst
liste_f_bing = [over_50_f_bing, under_50_f_bing] #st nst
einzeln_m_bing = [under_50_m_bing_e, over_50_m_bing_e] #st nst
einzeln_f_bing = [over_50_f_bing_e, under_50_f_bing_e] #st nst

br11 = np.arange(len(liste_m_bing)) 
br21= [x + barWidth for x in br11] 
br31 = [x + barWidth for x in br21] 
br41 = [x + barWidth for x in br31] 

plt.bar(br11, liste_m_bing, color ='y', width = barWidth, 
        edgecolor ='grey', label ='männlich (Liste)') 
plt.bar(br21, liste_f_bing, color ='black', width = barWidth, 
        edgecolor ='grey', label ='weiblich (Liste)') 
plt.bar(br31, einzeln_m_bing, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='männlich (einzeln)') 
plt.bar(br41, einzeln_f_bing, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='weiblich (einzeln)')

plt.xlabel('(anti-) stereotypische Übersetzung Bing') 
plt.ylabel('Datenmenge') 
plt.xticks([r + barWidth for r in range(len(liste_m_bing))], ['stereotypisch', 'anti-stereotypisch'])  

plt.legend()
plt.show() 

#------------------------- Deepl -------------------------------
barWidth = 0.1
fig,ax = plt.subplots(figsize =(6, 4)) 

liste_m_deepl = [under_50_m_deepl,  over_50_m_deepl] #st nst
liste_f_deepl = [over_50_f_deepl, under_50_f_deepl] #st nst
einzeln_m_deepl = [under_50_m_deepl_e, over_50_m_deepl_e] #st nst
einzeln_f_deepl = [over_50_f_deepl_e, under_50_f_deepl_e] #st nst

br12 = np.arange(len(liste_m_deepl)) 
br22 = [x + barWidth for x in br12] 
br32 = [x + barWidth for x in br22] 
br42 = [x + barWidth for x in br32] 

plt.bar(br12, liste_m_deepl, color ='y', width = barWidth, 
        edgecolor ='grey', label ='männlich (Liste)') 
plt.bar(br22, liste_f_deepl, color ='black', width = barWidth, 
        edgecolor ='grey', label ='weiblich (Liste)') 
plt.bar(br32, einzeln_m_deepl, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='männlich (einzeln)') 
plt.bar(br42, einzeln_f_deepl, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='weiblich (einzeln)')

plt.xlabel('(anti-) stereotypische Übersetzung Deepl') 
plt.ylabel('Datenmenge') 
plt.xticks([r + barWidth for r in range(len(liste_m_deepl))], ['stereotypisch', 'anti-stereotypisch'])  

plt.legend()
plt.show()
#------------------------- Google -------------------------------
barWidth = 0.1
fig,ax = plt.subplots(figsize =(6, 4)) 

liste_m_google = [under_50_m_google,  over_50_m_google] #st nst
liste_f_google = [over_50_f_google, under_50_f_google] #st nst
einzeln_m_google = [under_50_m_google_e, over_50_m_google_e] #st nst
einzeln_f_google = [over_50_f_google_e, under_50_f_google_e] #st nst

br13 = np.arange(len(liste_m_google)) 
br23 = [x + barWidth for x in br13] 
br33 = [x + barWidth for x in br23] 
br43 = [x + barWidth for x in br33] 

plt.bar(br13, liste_m_google, color ='y', width = barWidth, 
        edgecolor ='grey', label ='männlich (Liste)') 
plt.bar(br23, liste_f_google, color ='black', width = barWidth, 
        edgecolor ='grey', label ='weiblich (Liste)') 
plt.bar(br33, einzeln_m_google, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='männlich (einzeln)') 
plt.bar(br43, einzeln_f_google, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='weiblich (einzeln)')

plt.xlabel('(anti-) stereotypische Übersetzung Google') 
plt.ylabel('Datenmenge') 
plt.xticks([r + barWidth for r in range(len(liste_m_google))], ['stereotypisch', 'anti-stereotypisch'])  

plt.legend()
plt.show()

#------------------------- Gpt -------------------------------
barWidth = 0.1
fig,ax = plt.subplots(figsize =(6, 4)) 

liste_m_gpt = [under_50_m_gpt,  over_50_m_gpt] #st nst
liste_f_gpt = [over_50_f_gpt, under_50_f_gpt] #st nst
einzeln_m_gpt = [under_50_m_gpt_e, over_50_m_gpt_e] #st nst
einzeln_f_gpt = [over_50_f_gpt_e, under_50_f_gpt_e] #st nst

br14 = np.arange(len(liste_m_gpt)) 
br24 = [x + barWidth for x in br14] 
br34 = [x + barWidth for x in br24] 
br44 = [x + barWidth for x in br34] 

plt.bar(br14, liste_m_gpt, color ='y', width = barWidth, 
        edgecolor ='grey', label ='männlich (Liste)') 
plt.bar(br24, liste_f_gpt, color ='black', width = barWidth, 
        edgecolor ='grey', label ='weiblich (Liste)') 
plt.bar(br34, einzeln_m_gpt, color ='yellow', width = barWidth, 
        edgecolor ='grey', label ='männlich (einzeln)') 
plt.bar(br44, einzeln_f_gpt, color ='grey', width = barWidth, 
        edgecolor ='grey', label ='weiblich (einzeln)')

plt.xlabel('(anti-) stereotypische Übersetzung Gpt') 
plt.ylabel('Datenmenge') 
plt.xticks([r + barWidth for r in range(len(liste_m_gpt))], ['stereotypisch', 'anti-stereotypisch'])  

plt.legend()
plt.show()

# %%
#vergleich zwischen Ü-tools-> M:F und stereotypisch und gendern

# %%
#------------------------- M:F zwischen Ü_Tools -------------------------------
barWidth = 0.1
fig,ax = plt.subplots(figsize =(12, 8)) 

bing = [percent_masc_bing, percent_fem_bing, percent_gendern_bing, 
        percent_masc_bing_e, percent_fem_bing_e, percent_gendern_bing_e]
deepl = [percent_masc_deepl, percent_fem_deepl, percent_gendern_deepl, 
         percent_masc_deepl_e, percent_fem_deepl_e, percent_gendern_deepl_e]
google = [percent_masc_google, percent_fem_google, percent_gendern_google, 
          percent_masc_google_e, percent_fem_google_e, percent_gendern_google_e]
gpt = [percent_masc_gpt, percent_fem_gpt, percent_gendern_gpt,
       percent_masc_gpt_e, percent_fem_gpt_e, percent_gendern_gpt_e]


br1 = np.arange(len(bing)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
br4 = [x + barWidth for x in br3] 


plt.bar(br1, bing, color ='lightblue', width = barWidth, 
        edgecolor ='grey', label ='Bing (Liste)') 
plt.bar(br2, deepl, color ='darkred', width = barWidth, 
        edgecolor ='grey', label ='Deepl (Liste)') 
plt.bar(br3, google, color ='y', width = barWidth, 
        edgecolor ='grey', label ='Google (Liste)') 
plt.bar(br4, gpt, color ='green', width = barWidth, 
        edgecolor ='grey', label ='GPT (Liste)')


plt.xlabel('geschlechtliche Bevorzugung bei der maschinellen Übersetzung') 
plt.ylabel('Datenmenge') 
plt.xticks([r + barWidth for r in range(len(bing))], 
        ['männlich (Liste)', 'männlich (Liste)', 'männlich/weiblich (Liste)',
    'weiblich (einzeln)', 'weiblich (einzeln)', 'männlich/weiblich (Liste)'])  

plt.legend()
plt.show()

# %%
#------------------------- (anti-)stereotypische Übersetzung zwischen Ü-Tools -------------------------------

barWidth = 0.1
fig,ax = plt.subplots(figsize =(20, 8)) 

bing = [under_50_m_bing, over_50_f_bing, over_50_m_bing, under_50_f_bing,
       under_50_m_bing_e, over_50_f_bing_e, over_50_m_bing_e, under_50_f_bing_e]
deepl = [under_50_m_deepl, over_50_f_deepl, over_50_m_deepl, under_50_f_deepl,
       under_50_m_deepl_e, over_50_f_deepl_e, over_50_m_deepl_e, under_50_f_deepl_e]
google = [under_50_m_google, over_50_f_google, over_50_m_google, under_50_f_google,
       under_50_m_google_e, over_50_f_google_e, over_50_m_google_e, under_50_f_google_e]
gpt = [under_50_m_gpt, over_50_f_gpt, over_50_m_gpt, under_50_f_gpt,
       under_50_m_gpt_e, over_50_f_gpt_e, over_50_m_gpt_e, under_50_f_gpt_e]



br1 = np.arange(len(bing)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
br4 = [x + barWidth for x in br3] 


plt.bar(br1, bing, color ='lightblue', width = barWidth, 
        edgecolor ='grey', label ='Bing (Liste)') 
plt.bar(br2, deepl, color ='darkred', width = barWidth, 
        edgecolor ='grey', label ='Deepl (Liste)') 
plt.bar(br3, google, color ='y', width = barWidth, 
        edgecolor ='grey', label ='Google (Liste)') 
plt.bar(br4, gpt, color ='green', width = barWidth, 
        edgecolor ='grey', label ='GPT (Liste)')


plt.xlabel('geschlechtliche Bevorzugung bei der maschinellen Übersetzung') 
plt.ylabel('Datenmenge') 
plt.xticks([r + barWidth for r in range(len(bing))], 
        ['stereotypisch männlich (Liste)', 'stereotypisch weiblich (Liste)', 
         'anti-stereotypisch männlich (Liste)', 'anti-stereotypisch weiblich (Liste)',
   'stereotypisch männlich (einzeln)', 'stereotypisch weiblich (einzeln)', 
         'anti-stereotypisch männlich (einzeln)','anti-stereotypisch weiblich (einzeln)'])  

plt.legend()
plt.show()
